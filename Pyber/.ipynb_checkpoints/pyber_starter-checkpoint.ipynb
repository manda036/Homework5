# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
city_data = pd.read_csv(city_data_to_load)
ride_data = pd.read_csv(ride_data_to_load)
# city_data.head()
# ride_data.head()

# Combine the data into a single dataset
merged_data = pd.merge(ride_data, city_data, how="outer")

# Display the data table for preview
merged_data.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  Lake Jonathanshire  2018-04-07 20:51:11  31.25  4441251834598
# 2  Lake Jonathanshire  2018-03-09 23:45:55  19.89  2389495660448
# 3  Lake Jonathanshire  2018-04-07 18:09:21  24.28  7796805191168
# 4  Lake Jonathanshire  2018-01-02 14:14:50  13.89   424254840012
#
#    driver_count   type
# 0             5  Urban
# 1             5  Urban
# 2             5  Urban
# 3             5  Urban
# 4             5  Urban

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types
urban_data = merged_data.loc[merged_data["type"]=="Urban"]
urban_count = urban_data.groupby("city").count()
urban_xaxis= urban_count["ride_id"]
urban_average = urban_data.groupby("city").mean()
urban_yaxis = urban_average["fare"]
# urban_size = urban_data.groupby("city").unique()
# urban_circle_size = urban_size["driver_count"]

rural_data = merged_data.loc[merged_data["type"]=="Rural"]
rural_count = rural_data.groupby("city").count()
rural_xaxis= rural_count["ride_id"]
rural_average = rural_data.groupby("city").mean()
rural_yaxis = rural_average["fare"]
# rural_size = rural_data.groupby("city").unique()
# rural_circle_size = rural_sum["driver_count"]

suburban_data = merged_data.loc[merged_data["type"]=="Suburban"]
suburban_count = suburban_data.groupby("city").count()
suburban_xaxis= suburban_count["ride_id"]
suburban_average = suburban_data.groupby("city").mean()
suburban_yaxis = suburban_average["fare"]
# suburban_size = suburban_data.groupby("city").unique()
# suburban_circle_size = suburban_sum["driver_count"]

labels_list = ["Urban", "Suburban", "Rural"]

# Build the scatter plots for each city types
urban = plt.scatter(urban_xaxis, urban_yaxis, marker="o", s=urban_circle_size, facecolor="lightcoral", edgecolor="black", alpha=.75)
suburban = plt.scatter(suburban_xaxis, suburban_yaxis, marker="o", s=suburban_circle_size, facecolor="lightskyblue", edgecolor="black", alpha=.75)
rural = plt.scatter(rural_xaxis, rural_yaxis, marker="o", s=rural_circle_size, facecolor="gold", edgecolor="black", alpha=.75)

plt.title("Pyber Ride Sharing Data (2016)")
plt.xlabel("Total Number of Rides (per City)")
plt.ylabel("Average Fare ($)")

# Incorporate the other graph properties
plt.grid()

# Create a legend
plt.legend(title="City Types", labels=labels_list, loc="best")

# Incorporate a text label regarding circle size
plt.figtext("Note: Circle size correlates to driver count per city", color=black, fontsize=7, position = "right" )

# Save Figure
plt.savefig("Pyber_Scatter_Plot.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-ebe5f6dc6181> in <module>()
#      28 # Build the scatter plots for each city types
#      29 urban = plt.scatter(urban_xaxis, urban_yaxis, marker="o", s=urban_circle_size, facecolor="lightcoral", edgecolor="black", alpha=.75)
# ---> 30 suburban = plt.scatter(suburban_xaxis, suburban_yaxis, marker="o", s=suburban_circle_size, facecolor="lightskyblue", edgecolor="black", alpha=.75)
#      31 rural = plt.scatter(rural_xaxis, rural_yaxis, marker="o", s=rural_circle_size, facecolor="gold", edgecolor="black", alpha=.75)
#      32
#
# NameError: name 'suburban_circle_size' is not defined

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents
urbanfare = urban_data["fare"].sum()
suburbanfare = suburban_data["fare"].sum()
ruralfare = rural_data["fare"].sum()
percents= [urbanfare, suburbanfare, ruralfare]

# Build Pie Chart
labels = ["Urban", "Suburban", "Rural"]
colors = ["lightcoral", "lightskyblue", "gold"]
explode = [.1, 0, 0]

plt.pie(percents, labels=labels, colors=colors, explode=explode, autopct="%1.1f%%", shadow=True, startangle=270)
plt.axis("equal")
plt.title("% of Total Fare by City Type")

# Save Figure
plt.savefig("Total_Fare_Pie_Chart.png")

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents
urbanrides = urban_data["ride_id"].count()
suburbanrides = suburban_data["ride_id"].count()
ruralrides = rural_data["ride_id"].count()
percents2= [urbanrides, suburbanrides, ruralrides]

# Build Pie Chart
labels = ["Urban", "Suburban", "Rural"]
colors = ["lightcoral", "lightskyblue", "gold"]
explode = [.1, 0, 0]

plt.pie(percents2, labels=labels, colors=colors, explode=explode, autopct="%1.1f%%", shadow=True, startangle=270)
plt.axis("equal")
plt.title("% of Total Rides by City Type")

# Save Figure
plt.savefig("Total_Rides_Pie_Chart.png")

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents
urbandrivers = urban_data["driver_count"].sum()
suburbandrivers = suburban_data["driver_count"].sum()
ruraldrivers = rural_data["driver_count"].sum()
percents3= [urbandrivers, suburbandrivers, ruraldrivers]

# Build Pie Charts
labels = ["Urban", "Suburban", "Rural"]
colors = ["lightcoral", "lightskyblue", "gold"]
explode = [.1, 0, 0]

plt.pie(percents3, labels=labels, colors=colors, explode=explode, autopct="%1.1f%%", shadow=True, startangle=270)
plt.axis("equal")
plt.title("% of Total Drivers by City Type")

# Save Figure
plt.savefig("Total_Drivers_Pie_Chart.png")

# %%
# Show Figure
plt.show()
